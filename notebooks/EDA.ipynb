# %%
import pandas as pd
import matplotlib as plt
from pathlib import Path
import ast

pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', None)

# %%
path_app_list = Path('/home/alex/Documentos/meu-projeto/data/raw/app_list.csv')
path_steam_app_data = Path('/home/alex/Documentos/meu-projeto/data/raw/steam_app_data.csv')
path_steamspy_data = Path('/home/alex/Documentos/meu-projeto/data/raw/steamspy_data.csv')

# %%
df_app_list = pd.read_csv(path_app_list)
df_steam_app_data = pd.read_csv(path_steam_app_data)
df_steamspy_data = pd.read_csv(path_steamspy_data)

# %% [markdown]
# ### Inspecting the 'df_app_list' schema
#
# I want to check the number of columns, data type, and how many missing values we have

# %%
df_app_list.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29235 entries, 0 to 29234
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   appid   29235 non-null  int64
#  1   name    29230 non-null  object
# dtypes: int64(1), object(1)
# memory usage: 456.9+ KB

# %% [markdown]
# ** Observations: **
#
# - 5 null entries in 'name' columns
# - 'name' column with object type

# %% [markdown]
# ### Previewing the first and last records of 'df_app_list'
#
# This helps indentify obvius formatting issues, inconsistent values, and irregular patterns.

# %%
df_app_list
# Out:
#          appid                        name
# 0           10              Counter-Strike
# 1           20       Team Fortress Classic
# 2           30               Day of Defeat
# 3           40          Deathmatch Classic
# 4           50   Half-Life: Opposing Force
# ...        ...                         ...
# 29230  1065230             Room of Pandora
# 29231  1065570                   Cyber Gun
# 29232  1065650            Super Star Blast
# 29233  1066700  New Yankee 7: Deer Hunters
# 29234  1069460                   Rune Lord
#
# [29235 rows x 2 columns]

# %% [markdown]
# ** Observations: **
#
# Possible parent table with appid being primary key(PK)
# Switch column name "appid" to "steam_appid"

# %% [markdown]
# ### Checking missing values in ['name']
#
# I want to confirm whether NaNs have semantic meaning or represent missing data.

# %%
df_app_list[df_app_list['name'].isnull()]
# Out:
#         appid name
# 481     17760  NaN
# 7235   396420  NaN
# 9553   460250  NaN
# 22244  806160  NaN
# 27324  965340  NaN

# %% [markdown]
# ** Observations: **
#
# - The Nans represent missing data.
#
# ** Conclusion: **
#
# - Drop that 5 series

# %% [markdown]
# ###

# %%
df_steam_app_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29235 entries, 0 to 29234
# Data columns (total 39 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   type                     29086 non-null  object
#  1   name                     29234 non-null  object
#  2   steam_appid              29235 non-null  int64
#  3   required_age             29086 non-null  float64
#  4   is_free                  29086 non-null  object
#  5   controller_support       5998 non-null   object
#  6   dlc                      4975 non-null   object
#  7   detailed_description     29060 non-null  object
#  8   about_the_game           29060 non-null  object
#  9   short_description        29060 non-null  object
#  10  fullgame                 0 non-null      float64
#  11  supported_languages      29072 non-null  object
#  12  header_image             29086 non-null  object
#  13  website                  19252 non-null  object
# ...

# %% [markdown]
# So much columns with object type
# Many NaN entries, analysis requiered

# %%
df_steam_app_data.head(50)
# Out:
#     type                                 name  steam_appid  required_age  \
# 0   game                       Counter-Strike           10           0.0
# 1   game                Team Fortress Classic           20           0.0
# 2   game                        Day of Defeat           30           0.0
# 3   game                   Deathmatch Classic           40           0.0
# 4   game            Half-Life: Opposing Force           50           0.0
# 5   game                             Ricochet           60           0.0
# 6   game                            Half-Life           70           0.0
# 7   game       Counter-Strike: Condition Zero           80           0.0
# 8   game                Half-Life: Blue Shift          130           0.0
# 9   game                          Half-Life 2          220           0.0
# 10  game               Counter-Strike: Source          240           0.0
# 11  game                    Half-Life: Source          280           0.0
# ...

# %%
df_steam_app_data[df_steam_app_data['controller_support'].notnull()]
# Out:
#        type                                         name  steam_appid  \
# 20     game                                  Left 4 Dead          500
# 21     game                                Left 4 Dead 2          550
# 23     game                                     Portal 2          620
# 25     game             Counter-Strike: Global Offensive          730
# 81     game                          X3: Terran Conflict         2820
# ...     ...                                          ...          ...
# 29144  game                                    Hexa Path      1052760
# 29158  game                                   Foxyland 2      1053730
# 29190  game  Geometry May. I swear it's a nice free game      1057430
# 29219  game                               Peas Adventure      1062120
# 29232  game                             Super Star Blast      1065650
#
#        required_age is_free controller_support                       dlc  \
# ...

# %% [markdown]
# ### Observations
#
# - Column "controler_support" have 5998 'full' values the rest is NaN.
# - By context NaN mean that don't has controller suport than, replace NaN to 'not suported'

# %%
df_steamspy_data
# Out:
#          appid                        name           developer  \
# 0           10              Counter-Strike               Valve
# 1           20       Team Fortress Classic               Valve
# 2           30               Day of Defeat               Valve
# 3           40          Deathmatch Classic               Valve
# 4           50   Half-Life: Opposing Force    Gearbox Software
# ...        ...                         ...                 ...
# 29230  1065230             Room of Pandora         SHEN JIAWEI
# 29231  1065570                   Cyber Gun      Semyon Maximov
# 29232  1065650            Super Star Blast         EntwicklerX
# 29233  1066700  New Yankee 7: Deer Hunters  Yustas Game Studio
# 29234  1069460                   Rune Lord    Adept Studios GD
#
#                   publisher  score_rank  positive  negative  userscore  \
# 0                     Valve         NaN    124534      3339          0
# ...

# %%
df_steamspy_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29235 entries, 0 to 29234
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   appid            29235 non-null  int64
#  1   name             29230 non-null  object
#  2   developer        29037 non-null  object
#  3   publisher        28939 non-null  object
#  4   score_rank       58 non-null     float64
#  5   positive         29235 non-null  int64
#  6   negative         29235 non-null  int64
#  7   userscore        29235 non-null  int64
#  8   owners           29235 non-null  object
#  9   average_forever  29235 non-null  int64
#  10  average_2weeks   29235 non-null  int64
#  11  median_forever   29235 non-null  int64
#  12  median_2weeks    29235 non-null  int64
#  13  price            29206 non-null  float64
#  14  initialprice     29213 non-null  float64
#  15  discount         29213 non-null  float64
# ...

# %%
df_steamspy_data[df_steamspy_data['name'].isnull()]
# Out:
#         appid name       developer       publisher  score_rank  positive  \
# 481     17760  NaN             NaN             NaN         NaN         0
# 7235   396420  NaN             NaN             NaN         NaN        22
# 9553   460250  NaN  Jeroen Wimmers  Jeroen Wimmers         NaN        44
# 22244  806160  NaN    Paleno Games    Paleno Games         NaN         4
# 27324  965340  NaN      2nd Studio      2nd Studio         NaN        31
#
#        negative  userscore            owners  average_forever  average_2weeks  \
# 481           0          0       0 .. 20,000                0               0
# 7235          9          0  20,000 .. 50,000                0               0
# 9553          4          0       0 .. 20,000                0               0
# 22244        13          0       0 .. 20,000                0               0
# 27324         1          0       0 .. 20,000                0               0
#
# ...

# %%
df_app_list[df_app_list['name'].isnull()]
# Out:
#         appid name
# 481     17760  NaN
# 7235   396420  NaN
# 9553   460250  NaN
# 22244  806160  NaN
# 27324  965340  NaN

# %%
df_steam_app_data[df_steam_app_data['name'].isnull()]
# Out:
#       type name  steam_appid  required_age is_free controller_support  dlc  \
# 7235  game  NaN       396420           0.0    True                NaN  NaN
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                            detailed_description  \
# ...
